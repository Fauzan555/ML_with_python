# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\FAUZAN\Downloads\used_device_data.csv")

# %%
df
# Out:
#      device_brand       os  screen_size   4g   5g  rear_camera_mp  \
# 0           Honor  Android        14.50  yes   no            13.0
# 1           Honor  Android        17.30  yes  yes            13.0
# 2           Honor  Android        16.69  yes  yes            13.0
# 3           Honor  Android        25.50  yes  yes            13.0
# 4           Honor  Android        15.32  yes   no            13.0
# ...           ...      ...          ...  ...  ...             ...
# 3449         Asus  Android        15.34  yes   no             NaN
# 3450         Asus  Android        15.24  yes   no            13.0
# 3451      Alcatel  Android        15.80  yes   no            13.0
# 3452      Alcatel  Android        15.80  yes   no            13.0
# 3453      Alcatel  Android        12.83  yes   no            13.0
#
#       front_camera_mp  internal_memory  ram  battery  weight  release_year  \
# 0                 5.0             64.0  3.0   3020.0   146.0          2020
# ...

# %%
df.shape
# Out:
# (3454, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3454 entries, 0 to 3453
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   device_brand           3454 non-null   object
#  1   os                     3454 non-null   object
#  2   screen_size            3454 non-null   float64
#  3   4g                     3454 non-null   object
#  4   5g                     3454 non-null   object
#  5   rear_camera_mp         3275 non-null   float64
#  6   front_camera_mp        3452 non-null   float64
#  7   internal_memory        3450 non-null   float64
#  8   ram                    3450 non-null   float64
#  9   battery                3448 non-null   float64
#  10  weight                 3447 non-null   float64
#  11  release_year           3454 non-null   int64
#  12  days_used              3454 non-null   int64
#  13  normalized_used_price  3454 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# device_brand               0
# os                         0
# screen_size                0
# 4g                         0
# 5g                         0
# rear_camera_mp           179
# front_camera_mp            2
# internal_memory            4
# ram                        4
# battery                    6
# weight                     7
# release_year               0
# days_used                  0
# normalized_used_price      0
# normalized_new_price       0
# dtype: int64

# %%
df.describe().T
# Out:
#                         count         mean          std          min  \
# screen_size            3454.0    13.713115     3.805280     5.080000
# rear_camera_mp         3275.0     9.460208     4.815461     0.080000
# front_camera_mp        3452.0     6.554229     6.970372     0.000000
# internal_memory        3450.0    54.573099    84.972371     0.010000
# ram                    3450.0     4.036122     1.365105     0.020000
# battery                3448.0  3133.402697  1299.682844   500.000000
# weight                 3447.0   182.751871    88.413228    69.000000
# release_year           3454.0  2015.965258     2.298455  2013.000000
# days_used              3454.0   674.869716   248.580166    91.000000
# normalized_used_price  3454.0     4.364712     0.588914     1.536867
# normalized_new_price   3454.0     5.233107     0.683637     2.901422
#
#                                25%          50%          75%          max
# ...

# %%
df.describe(include="object")
# Out:
#        device_brand       os    4g    5g
# count          3454     3454  3454  3454
# unique           34        4     2     2
# top          Others  Android   yes    no
# freq            502     3214  2335  3302

# %%
#for numeracila column
for i in df.select_dtypes(include="number").columns:
    sns.kdeplot(data=df,x=i)
    plt.show()

# %%
#for categorical column
for i in df.select_dtypes(include="object").columns:
    sns.countplot(data=df,x=i)
    plt.show()

# %%
#for ouytlier
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
print(df.columns)
# Out:
# Index(['device_brand', 'os', 'screen_size', '4g', '5g', 'rear_camera_mp',
#        'front_camera_mp', 'internal_memory', 'ram', 'battery', 'weight',
#        'release_year', 'days_used', 'normalized_used_price',
#        'normalized_new_price'],
#       dtype='object')

# %%
#to undestand relationship
for i in ['device_brand', 'os', 'screen_size', '4g', '5g', 'rear_camera_mp',
       'front_camera_mp', 'internal_memory', 'ram', 'battery', 'weight',
       'release_year','normalized_used_price',
       'normalized_new_price']:
    sns.scatterplot(data=df,y='days_used',x=i)
    plt.show()

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data=df.select_dtypes(include="number").corr(),annot=True)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# device_brand               0
# os                         0
# screen_size                0
# 4g                         0
# 5g                         0
# rear_camera_mp           179
# front_camera_mp            2
# internal_memory            4
# ram                        4
# battery                    6
# weight                     7
# release_year               0
# days_used                  0
# normalized_used_price      0
# normalized_new_price       0
# dtype: int64

# %%
#for discrete use mode
for i in ["rear_camera_mp","front_camera_mp","internal_memory","ram"]:
    df[i].fillna(df[i].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3454 entries, 0 to 3453
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   device_brand           3454 non-null   object
#  1   os                     3454 non-null   object
#  2   screen_size            3454 non-null   float64
#  3   4g                     3454 non-null   object
#  4   5g                     3454 non-null   object
#  5   rear_camera_mp         3275 non-null   float64
#  6   front_camera_mp        3452 non-null   float64
#  7   internal_memory        3450 non-null   float64
#  8   ram                    3450 non-null   float64
#  9   battery                3448 non-null   float64
#  10  weight                 3447 non-null   float64
#  11  release_year           3454 non-null   int64
#  12  days_used              3454 non-null   int64
#  13  normalized_used_price  3454 non-null   float64
# ...

# %%
#for continuous
for i in ["battery","weight"]:
    df[i].fillna(df[i].median())

# %%
df.isnull().sum()
# Out:
# device_brand               0
# os                         0
# screen_size                0
# 4g                         0
# 5g                         0
# rear_camera_mp           179
# front_camera_mp            2
# internal_memory            4
# ram                        4
# battery                    6
# weight                     7
# release_year               0
# days_used                  0
# normalized_used_price      0
# normalized_new_price       0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['device_brand', 'os', 'screen_size', '4g', '5g', 'rear_camera_mp',
#        'front_camera_mp', 'internal_memory', 'ram', 'battery', 'weight',
#        'release_year', 'days_used', 'normalized_used_price',
#        'normalized_new_price'],
#       dtype='object')

# %%
df.drop('device_brand',axis=1,inplace=True)

# %%
print(df.columns)
# Out:
# Index(['os', 'screen_size', '4g', '5g', 'rear_camera_mp', 'front_camera_mp',
#        'internal_memory', 'ram', 'battery', 'weight', 'release_year',
#        'days_used', 'normalized_used_price', 'normalized_new_price'],
#       dtype='object')

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['os', '4g', '5g'], dtype='object')

# %%
print(df["4g"])
# Out:
# 0       yes
# 1       yes
# 2       yes
# 3       yes
# 4       yes
#        ...
# 3449    yes
# 3450    yes
# 3451    yes
# 3452    yes
# 3453    yes
# Name: 4g, Length: 3454, dtype: object

# %%
print(df["5g"])
# Out:
# 0        no
# 1       yes
# 2       yes
# 3       yes
# 4        no
#        ...
# 3449     no
# 3450     no
# 3451     no
# 3452     no
# 3453     no
# Name: 5g, Length: 3454, dtype: object

# %%
df["Four_G"] = df["4g"].map({"yes": 1, "no": 0}).astype(int)
df["Five_G"] = df["5g"].map({"yes": 1, "no": 0}).astype(int)

# %%
df.drop(["4g","5g"],inplace=True,axis=1)

# %%
print(df.columns)
# Out:
# Index(['os', 'screen_size', 'rear_camera_mp', 'front_camera_mp',
#        'internal_memory', 'ram', 'battery', 'weight', 'release_year',
#        'days_used', 'normalized_used_price', 'normalized_new_price', 'Four_G',
#        'Five_G'],
#       dtype='object')

# %%
df
# Out:
#            os  screen_size  rear_camera_mp  front_camera_mp  internal_memory  \
# 0     Android        14.50            13.0              5.0             64.0
# 1     Android        17.30            13.0             16.0            128.0
# 2     Android        16.69            13.0              8.0            128.0
# 3     Android        25.50            13.0              8.0             64.0
# 4     Android        15.32            13.0              8.0             64.0
# ...       ...          ...             ...              ...              ...
# 3449  Android        15.34             NaN              8.0             64.0
# 3450  Android        15.24            13.0              8.0            128.0
# 3451  Android        15.80            13.0              5.0             32.0
# 3452  Android        15.80            13.0              5.0             32.0
# 3453  Android        12.83            13.0              5.0             16.0
#
# ...

# %%
dummy=pd.get_dummies(data=df,columns=["os"],drop_first=True)

# %%
dummy
# Out:
#       screen_size  rear_camera_mp  front_camera_mp  internal_memory  ram  \
# 0           14.50            13.0              5.0             64.0  3.0
# 1           17.30            13.0             16.0            128.0  8.0
# 2           16.69            13.0              8.0            128.0  8.0
# 3           25.50            13.0              8.0             64.0  6.0
# 4           15.32            13.0              8.0             64.0  3.0
# ...           ...             ...              ...              ...  ...
# 3449        15.34             NaN              8.0             64.0  6.0
# 3450        15.24            13.0              8.0            128.0  8.0
# 3451        15.80            13.0              5.0             32.0  3.0
# 3452        15.80            13.0              5.0             32.0  2.0
# 3453        12.83            13.0              5.0             16.0  2.0
#
#       battery  weight  release_year  days_used  normalized_used_price  \
# ...

# %%
dummy.dtypes
# Out:
# screen_size              float64
# rear_camera_mp           float64
# front_camera_mp          float64
# internal_memory          float64
# ram                      float64
# battery                  float64
# weight                   float64
# release_year               int64
# days_used                  int64
# normalized_used_price    float64
# normalized_new_price     float64
# Four_G                     int64
# Five_G                     int64
# os_Others                   bool
# os_Windows                  bool
# os_iOS                      bool
# dtype: object

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.kdeplot(x=dummy["normalized_used_price"])

plt.subplot(1,2,1)
sns.kdeplot(x=np.log(dummy["normalized_used_price"]))
# Out:
# <Axes: xlabel='normalized_used_price', ylabel='Density'>

# %%
#now log tranformation to reduce the skewness in the target variable
dummy["normalized_used_price"]=np.log(dummy["normalized_used_price"])
dummy
# Out:
#       screen_size  rear_camera_mp  front_camera_mp  internal_memory  ram  \
# 0           14.50            13.0              5.0             64.0  3.0
# 1           17.30            13.0             16.0            128.0  8.0
# 2           16.69            13.0              8.0            128.0  8.0
# 3           25.50            13.0              8.0             64.0  6.0
# 4           15.32            13.0              8.0             64.0  3.0
# ...           ...             ...              ...              ...  ...
# 3449        15.34             NaN              8.0             64.0  6.0
# 3450        15.24            13.0              8.0            128.0  8.0
# 3451        15.80            13.0              5.0             32.0  3.0
# 3452        15.80            13.0              5.0             32.0  2.0
# 3453        12.83            13.0              5.0             16.0  2.0
#
#       battery  weight  release_year  days_used  normalized_used_price  \
# ...

# %%
#now import statsmodel to bulid model

import statsmodels.api as sm 
from sklearn.model_selection import train_test_split

# %%
x=dummy.drop("normalized_used_price",axis=1)
y=dummy["normalized_used_price"]

# %%
x_c=sm.add_constant(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_c,y,test_size=0.3,random_state=42)

# %%
if x_train.isna().sum().sum() == 0:
    model = sm.OLS(y_train, x_train.astype(float)).fit()  # Now should work
else:
    print("Missing values still exist! Check your preprocessing.")
# Out:
# Missing values still exist! Check your preprocessing.

# %%
print(x_train.isna().sum())  # Check for NaN values
# Out:
# const                     0
# screen_size               0
# rear_camera_mp          122
# front_camera_mp           1
# internal_memory           4
# ram                       3
# battery                   3
# weight                    5
# release_year              0
# days_used                 0
# normalized_new_price      0
# Four_G                    0
# Five_G                    0
# os_Others                 0
# os_Windows                0
# os_iOS                    0
# dtype: int64

# %%
x_train.fillna(x_train.mean(), inplace=True)  # Replace NaNs with column mean

# %%
if x_train.isna().sum().sum() == 0:
    model = sm.OLS(y_train, x_train.astype(float)).fit()  # Now should work
else:
    print("Missing values still exist! Check your preprocessing.")

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     normalized_used_price   R-squared:                       0.822
# Model:                               OLS   Adj. R-squared:                  0.820
# Method:                    Least Squares   F-statistic:                     737.2
# Date:                   Sat, 15 Mar 2025   Prob (F-statistic):               0.00
# Time:                           02:38:05   Log-Likelihood:                 3296.8
# No. Observations:                   2417   AIC:                            -6562.
# Df Residuals:                       2401   BIC:                            -6469.
# Df Model:                             15
# Covariance Type:               nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
y_predict=model.predict(x.test.astype(float))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23020\2196726350.py in ?()
# ----> 1 y_predict=model.predict(x.test.astype(float))
#
# ~\miniconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'test'

# %%
residual=y_test-y_predict
residual

# %%
#rmse
np.sqrt((residual**2).mean())

# %%
#maximum possible error
y_test.mean()

# %%
#now divide rmse to maximum possible error and it should be less than 10 pernent

# %%
#now validate the residula condition

# %%
residual.mean()

# %%
print(residual.skew())
sns.kdeplot(residual)

# %%
#if there is skewness in data then should be constant relationship between residula and predicted y
